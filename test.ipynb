# %%
import pandas as pd
import json
from io import StringIO

with open("275960.json") as f:
    data = json.load(f)

# Extract the log string
log_text = data["activitiesLog"]

# Convert to DataFrame
df = pd.read_csv(StringIO(log_text), sep=";")

print(df.head(10))
# Out:
#    day  timestamp               product  bid_price_1  bid_volume_1  \
# 0    1          0  INTARIAN_PEPPER_ROOT      12990.0          25.0
# 1    1          0     ASH_COATED_OSMIUM       9998.0          21.0
# 2    1        100  INTARIAN_PEPPER_ROOT      12993.0           8.0
# 3    1        100     ASH_COATED_OSMIUM      10000.0          15.0
# 4    1        200     ASH_COATED_OSMIUM       9998.0          30.0
# 5    1        200  INTARIAN_PEPPER_ROOT      12993.0           9.0
# 6    1        300  INTARIAN_PEPPER_ROOT      12993.0           8.0
# 7    1        300     ASH_COATED_OSMIUM      10000.0          12.0
# 8    1        400  INTARIAN_PEPPER_ROOT      12993.0          10.0
# 9    1        400     ASH_COATED_OSMIUM      10000.0          12.0
#
#    bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          NaN           NaN          NaN           NaN      13007.0
# 1          NaN           NaN          NaN           NaN      10016.0
# ...
